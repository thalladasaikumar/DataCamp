# %% [markdown]
# MatplotLib

# %%
import matplotlib.pyplot as plt

x = [1950, 1970, 1990, 2010]
y = [2.519, 3.547, 7.849, 10.254]

plt.plot(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt

x = [1950, 1970, 1990, 2010]
y = [2.519, 3.547, 7.849, 10.254]

plt.scatter(x, y)
plt.show()
